# %% [markdown]
# #### DATA UNDERSTANDING ###

# %%
import pandas as pd

# %%
df = pd.read_excel("school data.xlsx")
df.head()
# Out:
#   School_ID    District     Block Urban_Rural  %_Math_Score  %_Language_Score  \
# 0     SCH_1  District_C  Block_C1       Rural         43.32             48.87
# 1     SCH_2  District_A  Block_A3       Rural         81.98             83.18
# 2     SCH_3  District_B  Block_B1       Rural         44.68             46.38
# 3     SCH_4  District_A  Block_A1       Urban         44.86             35.20
# 4     SCH_5  District_C  Block_C1       Rural         47.41             47.94
#
#    %_Science_Score  Teacher_Student_Ratio  Avg_Teacher_Experience_Years  \
# 0            48.89                   40.1                           5.7
# 1            83.26                    NaN                           5.8
# 2            40.19                   29.9                           7.1
# 3            47.77                   24.6                           2.6
# 4            50.99                   39.8                           6.1
#
# ...

# %%
df.describe()
# Out:
#        %_Math_Score  %_Language_Score  %_Science_Score  Teacher_Student_Ratio  \
# count   4942.000000       5200.000000      5200.000000            4940.000000
# mean      60.055898         62.970896        61.338762              29.980951
# std       15.106160         16.569802        18.025438               9.957824
# min        0.326857          1.380000         1.510000               1.000000
# 25%       49.582500         51.520000        48.890000              23.100000
# 50%       59.850000         63.030000        61.150000              29.800000
# 75%       70.630000         74.452500        73.950000              36.600000
# max      107.344878        100.000000       100.000000             100.000000
#
#        Avg_Teacher_Experience_Years  Teacher_Trainings_Attended  \
# count                   5200.000000                 5200.000000
# mean                       8.096596                    1.995385
# std                        3.916906                    1.430434
# ...

# %%
df.shape
# Out:
# (5200, 17)

# %% [markdown]
# ### ROWS = 5200 , COLUMNS = 17

# %%
df.size
# Out:
# 88400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   School_ID                      5200 non-null   object
#  1   District                       5200 non-null   object
#  2   Block                          5200 non-null   object
#  3   Urban_Rural                    5200 non-null   object
#  4   %_Math_Score                   4942 non-null   float64
#  5   %_Language_Score               5200 non-null   float64
#  6   %_Science_Score                5200 non-null   float64
#  7   Teacher_Student_Ratio          4940 non-null   float64
#  8   Avg_Teacher_Experience_Years   5200 non-null   float64
#  9   Teacher_Trainings_Attended     5200 non-null   int64
#  10  Electricity_Available          5200 non-null   int64
#  11  Internet_Available             4940 non-null   float64
# ...

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %% [markdown]
# ### DATA CLEANING ###

# %%
df.isnull().sum()
# Out:
# School_ID                          0
# District                           0
# Block                              0
# Urban_Rural                        0
# %_Math_Score                     258
# %_Language_Score                   0
# %_Science_Score                    0
# Teacher_Student_Ratio            260
# Avg_Teacher_Experience_Years       0
# Teacher_Trainings_Attended         0
# Electricity_Available              0
# Internet_Available               260
# Functional_Toilets                 0
# Library_Available                  0
# %_Marginalized_Students            0
# %_Students_With_Home_Internet      0
# Parent_Literacy_Rate             259
# dtype: int64

# %%
df.head()
# Out:
#   School_ID    District     Block Urban_Rural  %_Math_Score  %_Language_Score  \
# 0     SCH_1  District_C  Block_C1       Rural         43.32             48.87
# 1     SCH_2  District_A  Block_A3       Rural         81.98             83.18
# 2     SCH_3  District_B  Block_B1       Rural         44.68             46.38
# 3     SCH_4  District_A  Block_A1       Urban         44.86             35.20
# 4     SCH_5  District_C  Block_C1       Rural         47.41             47.94
#
#    %_Science_Score  Teacher_Student_Ratio  Avg_Teacher_Experience_Years  \
# 0            48.89              40.100000                           5.7
# 1            83.26              29.980951                           5.8
# 2            40.19              29.900000                           7.1
# 3            47.77              24.600000                           2.6
# 4            50.99              39.800000                           6.1
#
# ...

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# School_ID                        0
# District                         0
# Block                            0
# Urban_Rural                      0
# %_Math_Score                     0
# %_Language_Score                 0
# %_Science_Score                  0
# Teacher_Student_Ratio            0
# Avg_Teacher_Experience_Years     0
# Teacher_Trainings_Attended       0
# Electricity_Available            0
# Internet_Available               0
# Functional_Toilets               0
# Library_Available                0
# %_Marginalized_Students          0
# %_Students_With_Home_Internet    0
# Parent_Literacy_Rate             0
# dtype: int64

# %% [markdown]
# #### 3 EDA (EXPLORATORY DATA ANALYSYS) ###

# %%
print(df.columns)
# Out:
# Index(['School_ID', 'District', 'Block', 'Urban_Rural', '%_Math_Score',
#        '%_Language_Score', '%_Science_Score', 'Teacher_Student_Ratio',
#        'Avg_Teacher_Experience_Years', 'Teacher_Trainings_Attended',
#        'Electricity_Available', 'Internet_Available', 'Functional_Toilets',
#        'Library_Available', '%_Marginalized_Students',
#        '%_Students_With_Home_Internet', 'Parent_Literacy_Rate'],
#       dtype='object')

# %%
df["%_Math_Score"].mean()
df["%_Math_Score"].median()
df["%_Math_Score"].std()
# Out:
# np.float64(14.726569314203324)

# %% [markdown]
# ### UNIVARIATE ANALYSYS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["%_Math_Score"], kde=True)
plt.show()

# %%
df["Urban_Rural"].value_counts()
# Out:
# Urban_Rural
# Rural    3579
# Urban    1621
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Urban_Rural"])
plt.show()

# %%
for col in num_cols:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram of {col}")
    plt.show()

# %% [markdown]
# ### BIVARIATE ANALYSYS

# %%
sns.scatterplot(x=df["%_Math_Score"], y=df["%_Science_Score"])
plt.show()

# %%
df[["%_Math_Score","%_Science_Score"]].corr()
# Out:
#                  %_Math_Score  %_Science_Score
# %_Math_Score         1.000000         0.769483
# %_Science_Score      0.769483         1.000000

# %%
sns.boxplot(x=df["Urban_Rural"], y=df["%_Math_Score"])
plt.show()

# %%
pd.crosstab(df["Electricity_Available"], df["Internet_Available"])
# Out:
# Internet_Available     0.000000  0.295344  1.000000
# Electricity_Available
# 0                           345        32       166
# 1                          3136       228      1293

# %% [markdown]
# ### CORRELATION ANALYSYS ###

# %%
corr = df.corr(numeric_only=True)
print(corr)
# Out:
#                                %_Math_Score  %_Language_Score  \
# %_Math_Score                       1.000000          0.835588
# %_Language_Score                   0.835588          1.000000
# %_Science_Score                    0.769483          0.815389
# Teacher_Student_Ratio              0.002643         -0.001899
# Avg_Teacher_Experience_Years      -0.018333         -0.016732
# Teacher_Trainings_Attended         0.007482          0.009758
# Electricity_Available              0.009344          0.010266
# Internet_Available                 0.008242         -0.002920
# Functional_Toilets                -0.004461          0.017188
# Library_Available                 -0.003085          0.011782
# %_Marginalized_Students            0.004794          0.013523
# %_Students_With_Home_Internet     -0.020812         -0.018282
# Parent_Literacy_Rate               0.011898          0.004858
#
#                                %_Science_Score  Teacher_Student_Ratio  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(x=df["Teacher_Student_Ratio"], y=df["%_Math_Score"])
plt.show()

# %%
import numpy as np

mask = np.triu(df.corr(numeric_only=True))

sns.heatmap(df.corr(numeric_only=True), mask=mask, annot=True)
plt.show()

# %% [markdown]
# ### INSIGHTS ###

# %% [markdown]
# ### 1. Strong Positive Relationship Among Academic Scores
# ### 2. Parent Literacy Positively Influences Student Performance ###
# ### 3. Internet Access Enhances Academic Outcomes
# ### 4. Higher Teacher-Student Ratio Negatively Impacts Performance
# ### 5. Teacher Experience Improves Student Results
# ### 6. Higher Percentage of Marginalized Students May Affect Performance
